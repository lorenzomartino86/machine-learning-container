# %% [markdown]
# ## Pandas datareader

# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2015,1,1)
end = datetime.datetime(2017,1,1)

# %%
facebook = web.DataReader('FB', 'google', start, end)

# %%
facebook.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2015-01-02  78.58  78.93  77.70  78.45  18177475
# 2015-01-05  77.98  79.25  76.86  77.19  26452191
# 2015-01-06  77.23  77.59  75.36  76.15  27399288
# 2015-01-07  76.76  77.36  75.82  76.15  22045333
# 2015-01-08  76.74  78.23  76.08  78.18  23960953

# %%
from pandas_datareader import Options

# %%
fb_options = Options('FB', 'google')

# %%
options_df = fb_options.get_options_data(expiry=fb_options.expiry_dates[0])

# %%
options_df.head()
# Out:
#                                             Last     Bid     Ask   Chg  \
# Strike Expiry     Type Symbol
# 5.0    2018-01-19 call FB180119C00005000  161.99  162.30  162.75 -3.51
#                   put  FB180119P00005000    0.01     NaN    0.03  0.00
# 10.0   2018-01-19 call FB180119C00010000  154.60  157.40  157.80  0.00
#                   put  FB180119P00010000    0.01     NaN    0.02  0.00
# 15.0   2018-01-19 call FB180119C00015000  158.00  152.25  152.85  0.00
#
#                                           PctChg  Vol  Open_Int Root  \
# Strike Expiry     Type Symbol
# 5.0    2018-01-19 call FB180119C00005000   -2.12  5.0    9351.0   FB
#                   put  FB180119P00005000    0.00  NaN    3053.0   FB
# 10.0   2018-01-19 call FB180119C00010000    0.00  NaN    2855.0   FB
#                   put  FB180119P00010000    0.00  NaN    2056.0   FB
# 15.0   2018-01-19 call FB180119C00015000    0.00  NaN     240.0   FB
#
# ...

# %% [markdown]
# #### Grab Forex indices (EUR/USD)

# %%
from pandas_datareader.oanda import get_oanda_currency_historical_rates
start = datetime.datetime(2015,1,1)
end = datetime.datetime(2017,9,1)
eurusd = web.get_data_yahoo('EURUSD=x', start, end)
eurusd.tail(100)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-04-02  1.066815  1.068376  1.064373  1.066883   1.066883     0.0
# 2017-04-03  1.067019  1.067464  1.063683  1.067008   1.067008     0.0
# 2017-04-04  1.067954  1.068913  1.065405  1.068034   1.068034     0.0
# 2017-04-05  1.067327  1.068399  1.063196  1.067247   1.067247     0.0
# 2017-04-06  1.064305  1.066041  1.061166  1.064464   1.064464     0.0
# 2017-04-09  1.058425  1.060783  1.057038  1.058201   1.058201     0.0
# 2017-04-10  1.059782  1.062948  1.057921  1.059760   1.059760     0.0
# 2017-04-11  1.060963  1.062383  1.059659  1.061132   1.061132     0.0
# 2017-04-12  1.067156  1.067806  1.061177  1.067065   1.067065     0.0
# 2017-04-13  1.061797  1.063151  1.060704  1.061639   1.061639     0.0
# 2017-04-16  1.061121  1.066985  1.060974  1.061053   1.061053     0.0
# 2017-04-17  1.064385  1.070859  1.063796  1.064453   1.064453     0.0
# ...

# %% [markdown]
# ## Quandl

# %%
import quandl

# %%
mydata = quandl.get('EIA/PET_RWTC_D')

# %%
mydata
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# 1986-01-09  26.03
# 1986-01-10  25.65
# 1986-01-13  25.08
# 1986-01-14  24.97
# 1986-01-15  25.18
# 1986-01-16  23.98
# 1986-01-17  23.63
# 1986-01-20  21.33
# 1986-01-21  20.61
# 1986-01-22  20.25
# 1986-01-23  19.93
# 1986-01-24  19.45
# 1986-01-27  20.87
# 1986-01-28  19.45
# 1986-01-29  19.61
# 1986-01-30  19.58
# 1986-01-31  18.95
# 1986-02-03  17.42
# 1986-02-04  15.58
# 1986-02-05  16.28
# 1986-02-06  16.60
# 1986-02-07  17.70
# 1986-02-10  16.78
# 1986-02-11  16.28
# 1986-02-12  15.74
# ...           ...
# 2017-07-03  46.02
# 2017-07-05  45.11
# 2017-07-06  45.52
# 2017-07-07  44.25
# 2017-07-10  44.40
# 2017-07-11  45.06
# 2017-07-12  45.48
# 2017-07-13  46.06
# 2017-07-14  46.53
# 2017-07-17  46.02
# 2017-07-18  46.40
# 2017-07-19  47.10
# 2017-07-20  46.73
# 2017-07-21  45.78
# 2017-07-24  46.21
# 2017-07-25  47.77
# 2017-07-26  48.58
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata.plot()

# %%
mydata = quandl.get('EIA/PET_RWTC_D', returns='numpy')

# %%
mydata
# Out:
# rec.array([(datetime.datetime(1986, 1, 2, 0, 0),  25.56),
#  (datetime.datetime(1986, 1, 3, 0, 0),  26.  ),
#  (datetime.datetime(1986, 1, 6, 0, 0),  26.53), ...,
#  (datetime.datetime(2017, 8, 10, 0, 0),  48.54),
#  (datetime.datetime(2017, 8, 11, 0, 0),  48.81),
#  (datetime.datetime(2017, 8, 14, 0, 0),  47.59)],
#           dtype=[('Date', 'O'), ('Value', '<f8')])

# %%
mydata = quandl.get('WIKI/AAPL')

# %%
mydata.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %% [markdown]
# Or grab a single column:

# %%
mydata = quandl.get('WIKI/AAPL.1')
mydata.head()
# Out:
#              Open
# Date
# 1980-12-12  28.75
# 1980-12-15  27.38
# 1980-12-16  25.37
# 1980-12-17  25.87
# 1980-12-18  26.63
